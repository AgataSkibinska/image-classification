# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train, y_train = pd.read_pickle("../data/training_data/train.pkl")

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (30134, 3136)
# (30134, 1)

# %% [markdown]
# Note: Dataset consist of 30134 examples

# %% [markdown]
# ### Labels analysis

# %%
df_label = pd.DataFrame(y_train,  columns=['label'])

# %%
num_classes = len(df_label['label'].unique())
num_classes
# Out:
# 36

# %%
df_label['label'].value_counts()
# Out:
# 14    3291
# 6     2527
# 22    2332
# 13    2157
# 2     2014
# 35    1924
# 34    1578
# 25    1442
# 3     1429
# 26    1235
# 8     1175
# 32    1073
# 17     841
# 4      735
# 29     701
# 16     664
# 33     561
# 12     548
# 18     425
# 21     394
# 10     343
# 20     332
# 9      324
# 1      301
# 28     287
# 5      191
# 15     179
# 27     168
# 0      164
# 31     158
# 19     152
# 11     141
# 7      127
# 24     118
# 23     102
# 30       1
# Name: label, dtype: int64

# %%
df_label['index'] = df_label.index
df_label
# Out:
#        label  index
# 0         26      0
# 1          0      1
# 2         13      2
# 3         13      3
# 4          6      4
# ...      ...    ...
# 30129     22  30129
# 30130     35  30130
# 30131     17  30131
# 30132     13  30132
# 30133      3  30133
#
# [30134 rows x 2 columns]

# %%
plt.figure(figsize=(20,8))
fig = sns.countplot(data=df_label, x='label')

fig.set_title('Class histogram')
fig.figure.savefig('images/class_histogram.png')

# %% [markdown]
# Note: this dataset is highly unbalanced - this needs to be adressed

# %% [markdown]
# ### Images analysis

# %%
np.unique(X_train)
# Out:
# array([0, 1], dtype=uint8)

# %% [markdown]
# Note: Matrices' values are already normalized into binary values.

# %%
def show_examples(X, y, label):
    n_examples = 3
    idxs_filtered = np.where(y == label)[0]
    
    X_filtered = X[idxs_filtered][:n_examples]
    
    if len(X_filtered) < n_examples:
        n_examples = len(X_filtered)
    X_reshaped = np.reshape(X_filtered, (-1, 56, 56))
    
    
    fig, axes = plt.subplots(1, n_examples, constrained_layout=True)
    # fig.subplots_adjust(top=1.5)
    fig.suptitle(f'Examples from class {label}')
    for i in range(n_examples):
        if n_examples == 1:
            axes.imshow(X_reshaped[i])
        else:
            axes[i].imshow(X_reshaped[i])
    fig.savefig(f'images/examples_label_{label}.png',  bbox_inches='tight')
    plt.show()

# %%
for label in range(num_classes):
    show_examples(X_train, y_train, label)

# %%
for label in range(num_classes):
    show_examples(X_train, y_train, label)

# %% [markdown]
# Note: We are dealing with MNIST like dataset.
